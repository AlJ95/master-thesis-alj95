# %%
import datasets

path = "/path/to/..."
dataset = datasets.load_dataset(path=path, "tag_classification", trust_remote_code=True)
dataset
# Out:
# ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\Besitzer\Projekte\master-thesis-alj95\.venv-312\Lib\site-packages\huggingface_hub\utils\_http.py:406, in hf_raise_for_status(response, endpoint_name)
#     405 try:
# --> 406     response.raise_for_status()
#     407 except HTTPError as e:
#
# File c:\Users\Besitzer\Projekte\master-thesis-alj95\.venv-312\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/datasets/NTU-NLP-sg/xCodeEval/resolve/main/tag_classification/validation/C%2523.jsonl
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# ...

# %%
# %pip list
# Out:
# Package                                  Version
# ---------------------------------------- -----------
# aiohappyeyeballs                         2.4.3
# aiohttp                                  3.11.0
# aiosignal                                1.3.1
# annotated-types                          0.7.0
# anyio                                    4.6.2.post1
# asttokens                                3.0.0
# attrs                                    24.2.0
# backoff                                  2.2.1
# certifi                                  2024.8.30
# charset-normalizer                       3.4.0
# click                                    8.1.7
# colorama                                 0.4.6
# comm                                     0.2.2
# dataclasses-json                         0.6.7
# datasets                                 3.1.0
# debugpy                                  1.8.12
# decorator                                5.1.1
# ...
